# %% [markdown]
# # NAME - ANANYA NAYAK

# %% [markdown]
# # Task :- To perfom Exploratory Data Analysis on Sample Superstore.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/Pavilion/Downloads/SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %% [markdown]
#  <b> 1.To display the name of columns in the dataset. </b>

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# <b> 2. To display the unique values in the column 'Ship Mode' </b>

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %% [markdown]
# <b> 3.To check the dimnesion of the dataset.</b>

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# <b> 4. To check the unique values of the column 'Category' </b>

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %% [markdown]
# <b> 5. To check the statistical parameters of the data set. </b>

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# <b> 6. To check the unique value of the country. It has only one country i.e. USA.</b>

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %% [markdown]
# 7. <b> To drop the column'Postal Code'and 'Country' columns as they dont hold any relevance for visualization.</b>

# %%
d2 = df.drop(['Postal Code','Country'],axis = 1,inplace = False)

# %%
d2
# Out:
#            Ship Mode    Segment             City       State Region  \
# 0       Second Class   Consumer        Henderson    Kentucky  South
# 1       Second Class   Consumer        Henderson    Kentucky  South
# 2       Second Class  Corporate      Los Angeles  California   West
# 3     Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4     Standard Class   Consumer  Fort Lauderdale     Florida  South
# ...              ...        ...              ...         ...    ...
# 9989    Second Class   Consumer            Miami     Florida  South
# 9990  Standard Class   Consumer       Costa Mesa  California   West
# 9991  Standard Class   Consumer       Costa Mesa  California   West
# 9992  Standard Class   Consumer       Costa Mesa  California   West
# 9993    Second Class   Consumer      Westminster  California   West
#
#              Category Sub-Category     Sales  Quantity  Discount    Profit
# 0           Furniture    Bookcases  261.9600         2      0.00   41.9136
# ...

# %% [markdown]
# <b> 8. To check for NULL values in the data set. </b>

# %%
plt.figure(figsize = (10,7))
sns.heatmap(d2.isnull(),yticklabels=False,cbar=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <b> INSIGHT :- From the above plot it can be seen that the dataset has no NULL values. </b>

# %% [markdown]
# # 1. Univariate Analysis

# %% [markdown]
# <b> A). To check which category has the highest number of sales. </b>

# %%
fig, axs = plt.subplots(2,2, figsize = (15,11))
sns.countplot(x = d2['Category'],data = df, ax = axs[0,0], palette = 'Paired')
sns.countplot(x = d2['Segment'], ax = axs[0,1], data = df,palette = 'YlOrBr')
sns.countplot(x = d2['Ship Mode'], ax = axs[1,0], data = df,palette = 'magma_r')
sns.countplot(x = d2['Region'], ax = axs[1,1], data = df,palette = 'gist_earth_r')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# <b> INSIGHTS :- </b>
#
# <b> I. In the first plot, Office Supplies category was the most sold section.</b> <br>
# <b> II.In the second plot, the Consumer segment goods were the most sold. </b> <br>
# <b> III.In the third plot, the Standard class were the highest number of buyers. </b> <br>
# <b> IV.In the fourth plot, the profit in West Region was the highest. </b>

# %% [markdown]
# <b> B). To check which state in the US has the highest number of sales.</b>

# %%
plt.figure(figsize= (17,19))
sns.countplot(x = df['State'],data = df,palette =  'nipy_spectral_r')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <b> INSIGHTS :- </b> <br>
# <b> I.) From the above plot it can be concluded that California has highest number of sales, followed by New York and then Texas. </b>

# %% [markdown]
# <b> C) To check how distributed are the numerical variables.</b>

# %%
fig, axs = plt.subplots(2,2, figsize = (15,11))
sns.boxplot(d2['Sales'], ax = axs[0,0], palette = 'pink_r')
sns.boxplot(d2['Quantity'], ax = axs[0,1], palette = 'inferno_r')
sns.boxplot(d2['Discount'], ax = axs[1,0], palette = 'nipy_spectral')
sns.boxplot(d2['Profit'], ax = axs[1,1], palette = 'BuGn')
# Out:
# <AxesSubplot:xlabel='Profit'>

# %% [markdown]
# <b> INSIGHT :- From the above plots it can be concluded that we have negative profit too. </b>

# %% [markdown]
# <b> D. To check which commodity has been most sold in Sub Category region, </b>

# %%
plt.figure(figsize = (12,10))
sns.countplot(x = df['Sub-Category'],data = df, palette =  'gist_stern_r')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# <b> INSIGHT :- Binder is the most preffered product among the sold items. </b>

# %% [markdown]
# <b> E) To find out the percentage wise share among Sub Category. </b>

# %%
p1 = d2['Sub-Category'].value_counts()
p1.plot.pie(autopct='%1.2f%%',figsize = (13,13))
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %% [markdown]
# <b> INSIGHT :- From the above Pie chart it can be concluded that Binders is the most preffered consumer material among the buyers. </b>

# %% [markdown]
# # 2. Bivariate Analysis

# %% [markdown]
# <b> I. To figure out the goods sold (category wise) in respective regions of USA. </b>

# %%
plt.figure(figsize= (13,10))
sns.countplot(x = d2['Region'],data = d2, hue = d2['Category'],palette = 'prism')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# <b> From the above figure it can be concluded that West Region has highest number of sales in all categories. </b>

# %% [markdown]
# <b> II. To check whcich state has the highest profit. </b>

# %%
v = d2.groupby(["State"])[['Profit']].sum()
m = v.sort_values(by = 'Profit',ascending = False)b
m.plot(kind = 'bar',figsize = (20,10), color = 'green')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# <b> INSIGHT :- From the above plot California witnessed the highest profit with a figure of 76,381.</b>

# %% [markdown]
# <b> III. To check which consumer segment was the most preffered among various economic groups. </b>

# %%
plt.figure(figsize= (13,10))
sns.countplot(x = d2['Ship Mode'],hue = d2['Category'],data = d2, color = 'maroon')
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# <b> INSIGHT :- It was observed that 'Standard Class' was the highest buyer in all goods. </b>

# %% [markdown]
# <b> IV. To check which segment has the highest number of sales.</b>

# %%
a = d2.groupby(["Segment"])[['Sales']].count()
b = a.sort_values(by = 'Sales',ascending = False)
b.plot(kind = 'bar',figsize = (11,10), color = 'red')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# <b> INSIGHT :- It was observed that Consumer commodities were sold the highest.</b>

# %% [markdown]
# <b> V. To check in which state sales was the highest </b>

# %%
d2['State'].value_counts().plot(kind = 'bar',figsize = (22,17), color = 'Purple' )
plt.xlabel('States')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# <b> INSIGHT :- It was found that in California the sales were highest. </b>

# %% [markdown]
# <b> VI:- To check which region has the highest profit share. </b>

# %%
p3 = d2.groupby('Region').sum()['Profit']
p3.plot.pie(autopct='%1.2f%%',figsize = (13,13))
# Out:
# <AxesSubplot:ylabel='Profit'>

# %% [markdown]
# <b> INSIGHT :- It was found that WEST region dominated the most in Profit share. </b>

# %% [markdown]
# # 3. Multivariate Analysis

# %%
plt.figure(figsize = (10,10))
sns.heatmap(d2.corr(),annot =True, cmap = 'RdYlGn_r',linewidth = 1, linecolor = 'black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <b> INSIGHT :- Fom the above plot it can be found that Profit and Sales are moderately related, whereas other variables'
#     negatively correlated. </b>

# %% [markdown]
# <b> CONCLUSIONS :- </b>
#
# <b>1. The sample store should focus on improving profit in Central and Eastern region of USA. </b><br>
# <b>2. Home Office and Corporate segment commodites are two areas where the store can focus on to improve sales and profit.</b><br>
# <b>3. In the Sub Category section the store needs to consider those essentials which registered single digit sales.<b><br>
# <b>4. In some states, negative profit was observed, which is a metter of concern for the store.<b><br>
# <b>5. The store should try improving sales for First class and second class economic groups. </b><br>

# %% [markdown]
# # THANK YOU
